# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

# %%
# !nvidia-smi
# Out:
# Mon Dec  5 05:15:07 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   69C    P0    29W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 14.9 MB/s
# ...
#      |████████████████████████████████| 168 kB 94.8 MB/s
# ...
#      |████████████████████████████████| 182 kB 88.4 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 168 kB 96.9 MB/s
# ...
#      |████████████████████████████████| 166 kB 100.8 MB/s
# ...
#      |████████████████████████████████| 166 kB 78.9 MB/s
# ...
#      |████████████████████████████████| 162 kB 102.8 MB/s
# ...
#      |████████████████████████████████| 162 kB 96.2 MB/s
# ...
#      |████████████████████████████████| 158 kB 102.8 MB/s
# ...
#      |████████████████████████████████| 157 kB 99.6 MB/s
# ...
#      |████████████████████████████████| 157 kB 105.4 MB/s
# ...
#      |████████████████████████████████| 157 kB 104.5 MB/s
# ...
#      |████████████████████████████████| 157 kB 103.0 MB/s
# ...
#      |████████████████████████████████| 157 kB 101.8 MB/s
# ...

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import wandb

wandb.init(project="foreign-object-detection-final", entity="ashokkakunuri")
# Out:
# wandb: Currently logged in as: foreignobjectproject (ashokkakunuri). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221204_052807-22yxh7ev</code>
# Syncing run <strong><a href="https://wandb.ai/ashokkakunuri/foreign-object-detection-final/runs/22yxh7ev" target="_blank">sunny-plant-1</a></strong> to <a href="https://wandb.ai/ashokkakunuri/foreign-object-detection-final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/ashokkakunuri/foreign-object-detection-final/runs/22yxh7ev?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
cd /content/drive/MyDrive/Project3/yolov5
# Out:
# /content/drive/MyDrive/Project3/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 150  --data foreign_object.yaml --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object5/weights/best.pt --name yolo_foreign_object_final --cache
# Out:
# wandb: Currently logged in as: foreignobjectproject (ashokkakunuri). Use `wandb login --relogin` to force relogin
# train: weights=/content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object5/weights/best.pt, cfg=, data=foreign_object.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolo_foreign_object_final, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# requirements: YOLOv5 requirements "ipython" "thop>=0.1.1" not found, attempting AutoUpdate...
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 392), started 0:03:49 ago. (Use '!kill 392' to kill it.)

# %%
# !python detect.py --img 640 --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_final/weights/best.pt --source ../dataset/images/test --name yolo_det
# Out:
# detect: weights=['/content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_final/weights/best.pt'], source=../dataset/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolo_det, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: YOLOv5 requirements "gitpython" "ipython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 2 packages updated per /content/drive/MyDrive/Project3/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-17-g7845cea Python-3.8.15 torch-1.12.1+cu113 CPU
#
# ...

# %%
# !python val.py --task test
# Out:
# val: data=data/coco128.yaml, weights=yolov5s.pt, batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-17-g7845cea Python-3.8.15 torch-1.12.1+cu113 CPU
#
# ...
# 100% 14.1M/14.1M [00:01<00:00, 12.4MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
#
# Dataset not found ⚠️, missing paths ['/content/drive/MyDrive/Project3/datasets/coco128/images/train2017']
# ...
# 100% 6.66M/6.66M [00:00<00:00, 10.3MB/s]
# Dataset download success ✅ (3.7s), saved to /content/drive/MyDrive/Project3/datasets
# ...
# 100% 755k/755k [00:00<00:00, 27.0MB/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Project3/yolov5/utils/dataloaders.py", line 464, in __init__
#     p = Path(p)  # os-agnostic
# ...

# %%
# !python val.py  --img 640 --weights /content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_final/weights/best.pt --data foreign_object.yaml --task test
# Out:
# val: data=/content/drive/MyDrive/Project3/yolov5/data/foreign_object.yaml, weights=['/content/drive/MyDrive/Project3/yolov5/runs/train/yolo_foreign_object_final/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: YOLOv5 requirements "gitpython" "ipython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 2 packages updated per /content/drive/MyDrive/Project3/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v7.0-17-g7845cea Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# ...

# %%
# !python val.py --data foreign_object.yaml --task test
